# %%
from pytexit import py2tex
import sympy as sp
import numpy as np

# %%
import numpy as np
import sympy as sp

# Define NumPy arrays
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

# Convert NumPy arrays to SymPy matrices
A_sym = sp.Matrix(A)
B_sym = sp.Matrix(B)

# Perform some operations
C_sym = A_sym + B_sym
D_sym = A_sym * B_sym
E_sym = A_sym.T

# Generate LaTeX code
C_latex = sp.latex(C_sym)
D_latex = sp.latex(D_sym)
E_latex = sp.latex(E_sym)

# Print LaTeX code
print("A + B in LaTeX:", C_latex)
print("A * B in LaTeX:", D_latex)
print("A^T in LaTeX:", E_latex)
# Out:
# A + B in LaTeX: \left[\begin{matrix}6 & 8\\10 & 12\end{matrix}\right]
# A * B in LaTeX: \left[\begin{matrix}19 & 22\\43 & 50\end{matrix}\right]
# A^T in LaTeX: \left[\begin{matrix}1 & 3\\2 & 4\end{matrix}\right]

# %%
segmentation_masks = np.random.randint(0, 2, (480, 640))
depth_image = np.random.randint(0, 6000, (480, 640))

# Convert NumPy arrays to SymPy matrices
segmentation_masks_sym = sp.Matrix(segmentation_masks)
depth_image_sym = sp.Matrix(depth_image)

depth_image_i = depth_image_sym

mul = segmentation_masks_sym.T * depth_image_i

mul_latex = sp.latex(mul)
mul_latex
# Out:
# '\\left[\\begin{array}{...}647247 & 653235 & 652896 & 659386 & 643621 & 655928 & 638990 & 643875 & 630893 & 605052 & 628108 & 642703 & 628818 & 624184 & 610097 & 658626 & 646167 & 642239 & 698418 & 680844 & 620377 & 626707 & 651222 & 689565 & 624748 & 617032 & 644074 & 608142 & 629256 & 655891 & 686766 & 646120 & 639472 & 662389 & 653868 & 597040 & 619346 & 649442 & 610923 & 649891 & 626220 & 639842 & 620070 & 590525 & 590117 & 631762 & 660412 & 651931 & 615398 & 655853 & 637421 & 646649 & 615986 & 639025 & 609112 & 618893 & 646169 & 655850 & 674991 & 664450 & 655722 & 654115 & 622448 & 634154 & 661707 & 658477 & 636474 & 624547 & 658079 & 668687 & 643764 & 674992 & 652738 & 626203 & 622087 & 623898 & 610239 & 633834 & 637263 & 605112 & 612298 & 666235 & 624669 & 668155 & 629297 & 685471 & 641393 & 698672 & 623718 & 614776 & 634402 & 611551 & 659491 & 683921 & 633091 & 665454 & 660324 & 695877 & 678438 & 604742 & 641913 & 629209 & 639895 & 648784 & 611709 & 665981 & 617453 & 639777 &
# ...
